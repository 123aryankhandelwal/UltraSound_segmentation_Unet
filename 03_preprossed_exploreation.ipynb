# %%
#import libraries
import os
import pandas as pd
import matplotlib.pyplot as plt
import h5py

# %%
f = h5py.File("Dataset_list/train_image_dataset.hdf5", "r")

# %%
train_masks = f["train 2ch masks"]
train_masks.shape
# Out:
# (900, 256, 256, 1)

# %%
plt.imshow(train_masks[150,:,:,0])
plt.show()

# %%
f.close()

# %%
f1 = h5py.File("Dataset_list/image_test_dataset.hdf5", "r")

# %%
test_frames = f1["test 2ch frames"]
test_frames.shape
# Out:
# (100, 256, 256, 1)

# %%
plt.imshow(test_frames[50,:,:,0])
plt.show()
